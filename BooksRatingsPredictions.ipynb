# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt; plt.style.use('ggplot')
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import pycaret.regression as reg 
import pycaret.classification as clf
from imblearn.over_sampling import SMOTE
from collections import Counter


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Data

# %%
df = pd.read_csv('books.csv', on_bad_lines='skip')

# %%
df.shape
# Out:
# (11123, 12)

# %% [markdown]
# # Renaming num_pages Column

# %%
df.rename(columns={'  num_pages': 'num_pages'}, inplace=True)

# %% [markdown]
# # Creating Audiobook Column

# %%
df['audiobook'] = df['publisher'].str.contains('audio|audiobook|audiobooks', case=False, na=False).astype(int)

# %% [markdown]
# # Correcting num_pages And audiobook Information

# %%
df.loc[df['title'] == 'The Mask of the Enchantress', 'num_pages'] = 327
df.loc[df['title'] == 'The Da Vinci Code (Robert Langdon #2)', 'num_pages'] = 489
df.loc[df['title'] == 'Caligula and Three Other Plays', 'num_pages'] = 302
df.loc[df['title'] == 'Dirty White Boys', 'num_pages'] = 496
df.loc[df['title'] == 'A Caribbean Mystery', 'num_pages'] = 224
df.loc[df['title'] == 'Open House', 'num_pages'] = 272
df.loc[df['title'] == "Gulliver's Travels", 'num_pages'] = 306
df.loc[df['title'] == 'The Far Pavilions', 'num_pages'] = 958
df.loc[df['title'] == 'Blind Willow Sleeping Woman: 24 Stories', 'num_pages'] = 362
df.loc[df['title'] == 'One Two Buckle My Shoe (Hercule Poirot #23)', 'audiobook'] = 1
df.loc[df['title'] == 'The Feynman Lectures on Physics Vols 7-8', 'audiobook'] = 1
df.loc[df['title'].str.contains("The Botany of Desire: A Plant's-Eye View of"), 'num_pages'] = 304
df.loc[df['title'] == 'Here We All Are', 'audiobook'] = 1
df.loc[df['title'] == 'Since "Silent Spring"', 'num_pages'] = 297
df.loc[df['isbn'].str.contains("1594839417"), 'num_pages'] = 388
df.loc[df['isbn'].str.contains("1594832285"), 'num_pages'] = 454
df.loc[df['title'] == 'The Chessmen of Mars (Barsoom #5)', 'audiobook'] = 1
df.loc[df['title'] == 'Tiempo De Matar', 'num_pages'] = 648
df.loc[df['title'] == 'Turn of the Cards', 'num_pages'] = 221
df.loc[df['title'] == 'First King of Shannara (Shannara Prequel)', 'num_pages'] = 448
df.loc[df['title'].str.contains("Return to the Planet of the Apes #2: Escape fr"), 'num_pages'] = 192
df.loc[df['title'].str.contains("The Complete Science Fiction Treasury of H.G."), 'num_pages'] = 860
df.loc[df['isbn'].str.contains("1400102952"), 'num_pages'] = 362
df.loc[df['title'] == 'Der Prozess', 'num_pages'] = 208
df.loc[df['title'] == 'The Celestine Prophecy', 'num_pages'] = 247
df.loc[df['isbn'] == '1572703857', 'audiobook'] = 1
df.loc[df['title'] == 'Madame Bovary', 'num_pages'] = 329
df.loc[df['title'] == 'The Best American Mystery Stories 2004', 'num_pages'] = 432

# %% [markdown]
# # Filtering Dataset

# %% [markdown]
# ### Dropping rows that belong to books with 0 pages that aren't audiobooks and dropping rows that especifically say "NOT A BOOK"

# %%
drop_condition = (df['num_pages'] == 0) & (df['audiobook'] == 0)

df.drop(df[drop_condition].index, inplace=True)
df = df[df['authors'] != 'NOT A BOOK']

# %%
df.shape
# Out:
# (11111, 13)

# %% [markdown]
# # Checking For Null Values

# %%
df.isna().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
# num_pages             0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# audiobook             0
# dtype: int64

# %% [markdown]
# # Convert All Values to Lowercase

# %%
df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
#        bookID                                              title  \
# 0           1  harry potter and the half-blood prince (harry ...
# 1           2  harry potter and the order of the phoenix (har...
# 2           4  harry potter and the chamber of secrets (harry...
# 3           5  harry potter and the prisoner of azkaban (harr...
# 4           8  harry potter boxed set  books 1-5 (harry potte...
# ...       ...                                                ...
# 11118   45631   expelled from eden: a william t. vollmann reader
# 11119   45633                        you bright and risen angels
# 11120   45634                    the ice-shirt (seven dreams #1)
# 11121   45639                                        poor people
# 11122   45641                        las aventuras de tom sawyer
#
#                                                  authors  average_rating  \
# 0                             j.k. rowling/mary grandpré            4.57
# 1                             j.k. rowling/mary grandpré            4.49
# 2                                           j.k. rowling            4.42
# 3                             j.k. rowling/mary grandpré            4.56
# 4                             j.k. rowling/mary grandpré            4.78
# ...                                                  ...             ...
# 11118  william t. vollmann/larry mccaffery/michael he...            4.06
# 11119                                william t. vollmann            4.08
# 11120                                william t. vollmann            3.96
# 11121                                william t. vollmann            3.72
# 11122                                         mark twain            3.91
#
#              isbn         isbn13 language_code  num_pages  ratings_count  \
# 0      0439785960  9780439785969           eng        652        2095690
# 1      0439358078  9780439358071           eng        870        2153167
# 2      0439554896  9780439554893           eng        352           6333
# 3      043965548x  9780439655484           eng        435        2339585
# 4      0439682584  9780439682589           eng       2690          41428
# ...           ...            ...           ...        ...            ...
# 11118  1560254416  9781560254416           eng        512            156
# 11119  0140110879  9780140110876           eng        635            783
# 11120  0140131965  9780140131963           eng        415            820
# 11121  0060878827  9780060878825           eng        434            769
# 11122  8497646983  9788497646987           spa        272            113
#
#        text_reviews_count publication_date        publisher  audiobook
# 0                   27591        9/16/2006  scholastic inc.          0
# 1                   29221         9/1/2004  scholastic inc.          0
# 2                     244        11/1/2003       scholastic          0
# 3                   36325         5/1/2004  scholastic inc.          0
# 4                     164        9/13/2004       scholastic          0
# ...                   ...              ...              ...        ...
# 11118                  20       12/21/2004    da capo press          0
# 11119                  56        12/1/1988    penguin books          0
# 11120                  95         8/1/1993    penguin books          0
# 11121                 139        2/27/2007             ecco          0
# 11122                  12        5/28/2006    edimat libros          0
#
# [11111 rows x 13 columns]

# %% [markdown]
# # Drop useless columns

# %%
df = df.drop(columns=['bookID', 'isbn', 'isbn13'])

# %% [markdown]
# # Fix Language Column

# %%
df['language_code'] = df['language_code'].astype(str)

df.loc[df['language_code'].str.contains('en'), 'language_code'] = 'eng'

counts = df['language_code'].value_counts()
df['language_code'] = df['language_code'].apply(lambda x: 'other' if counts[x] < 5 else x)

df.language_code.value_counts()
# Out:
# language_code
# eng      10528
# spa        218
# fre        144
# ger         99
# jpn         46
# mul         19
# other       17
# zho         14
# grc         11
# por         10
# ita          5
# Name: count, dtype: int64

# %% [markdown]
# # Drop Duplicate Rows

# %%
df = df.drop_duplicates()

# %% [markdown]
# # Check For Unique Values Per Column

# %%
for col in df.columns:
    print(df[col].value_counts(), '\n')
# Out:
# title
# The Iliad                                                              9
# The Brothers Karamazov                                                 9
# Gulliver's Travels                                                     8
# Anna Karenina                                                          8
# The Odyssey                                                            8
#                                                                       ..
# The Noonday Demon: An Anatomy of Depression                            1
# My Secret: A PostSecret Book                                           1
# The Secret Lives of Men and Women: A PostSecret Book                   1
# The Secret Life of Houdini: The Making of America's First Superhero    1
# Las aventuras de Tom Sawyer                                            1
# Name: count, Length: 10336, dtype: int64
#
# authors
# P.G. Wodehouse                                            40
# Stephen King                                              40
# Rumiko Takahashi                                          39
# Orson Scott Card                                          35
# Agatha Christie                                           33
#                                                           ..
# David Weisman/Melissa Painter                              1
# Ian Glasper                                                1
# Legs McNeil/Gillian McCain                                 1
# Adam Woog                                                  1
# William T. Vollmann/Larry McCaffery/Michael Hemmingson     1
# Name: count, Length: 6633, dtype: int64
#
# average_rating
# 4.00    218
# 3.96    195
# 4.02    178
# 3.94    176
# 4.07    172
#        ...
# 2.55      1
# 4.91      1
# 2.99      1
# 3.10      1
# 2.33      1
# Name: count, Length: 209, dtype: int64
#
# language_code
# eng      10528
# spa        218
# fre        144
# ger         99
# jpn         46
# mul         19
# other       17
# zho         14
# grc         11
# por         10
# ita          5
# Name: count, dtype: int64
#
# num_pages
# 288     230
# 192     222
# 320     218
# 256     207
# 352     202
#        ...
# 1840      1
# 1046      1
# 976       1
# 1440      1
# 22        1
# Name: count, Length: 998, dtype: int64
#
# ratings_count
# 3         80
# 0         79
# 1         76
# 4         71
# 2         70
#           ..
# 21507      1
# 6970       1
# 108440     1
# 66503      1
# 783        1
# Name: count, Length: 5294, dtype: int64
#
# text_reviews_count
# 0        619
# 1        456
# 2        351
# 3        263
# 4        245
#         ...
# 4496       1
# 8251       1
# 13070      1
# 688        1
# 1830       1
# Name: count, Length: 1822, dtype: int64
#
# publication_date
# 10/1/2005     56
# 11/1/2005     53
# 9/1/2006      51
# 10/1/2006     48
# 11/1/2006     40
#               ..
# 9/28/2001      1
# 9/1/1925       1
# 1/3/2012       1
# 10/3/1983      1
# 10/11/2003     1
# Name: count, Length: 3674, dtype: int64
#
# publisher
# Vintage                        318
# Penguin Books                  261
# Penguin Classics               184
# Mariner Books                  150
# Ballantine Books               144
#                               ...
# Westholme Publishing             1
# University of Calgary Press      1
# Marlowe & Company                1
# University Press of America      1
# VeloPress                        1
# Name: count, Length: 2289, dtype: int64
#
# audiobook
# 0    10931
# 1      180
# Name: count, dtype: int64

# %% [markdown]
# # Creating author_popularity Column

# %%
author_popularity = df['authors'].value_counts().reset_index()
author_popularity.columns = ['authors', 'author_popularity']
df = pd.merge(df, author_popularity, on='authors', how='left')

# %% [markdown]
# # Creating publisher_popularity Column

# %%
publisher_popularity = df['publisher'].value_counts().reset_index()
publisher_popularity.columns = ['publisher', 'publisher_popularity']
df = pd.merge(df, publisher_popularity, on='publisher', how='left')

# %% [markdown]
# # Creating year Column

# %%
df['publication_date'] = pd.to_datetime(df['publication_date'], errors='coerce')

# %%
df['year'] = df['publication_date'].dt.year

# %%
df = df.drop(columns=['publication_date'])

# %% [markdown]
# # Create title_length column

# %%
df['title_length'] = df['title'].apply(len)
df
# Out:
#                                                    title  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 2      Harry Potter and the Chamber of Secrets (Harry...
# 3      Harry Potter and the Prisoner of Azkaban (Harr...
# 4      Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                  ...
# 11106   Expelled from Eden: A William T. Vollmann Reader
# 11107                        You Bright and Risen Angels
# 11108                    The Ice-Shirt (Seven Dreams #1)
# 11109                                        Poor People
# 11110                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11106  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11107                                William T. Vollmann            4.08
# 11108                                William T. Vollmann            3.96
# 11109                                William T. Vollmann            3.72
# 11110                                         Mark Twain            3.91
#
#       language_code  num_pages  ratings_count  text_reviews_count  \
# 0               eng        652        2095690               27591
# 1               eng        870        2153167               29221
# 2               eng        352           6333                 244
# 3               eng        435        2339585               36325
# 4               eng       2690          41428                 164
# ...             ...        ...            ...                 ...
# 11106           eng        512            156                  20
# 11107           eng        635            783                  56
# 11108           eng        415            820                  95
# 11109           eng        434            769                 139
# 11110           spa        272            113                  12
#
#              publisher  audiobook  author_popularity  publisher_popularity  \
# 0      Scholastic Inc.          0                  6                    13
# 1      Scholastic Inc.          0                  6                    13
# 2           Scholastic          0                 11                    33
# 3      Scholastic Inc.          0                  6                    13
# 4           Scholastic          0                  6                    33
# ...                ...        ...                ...                   ...
# 11106    Da Capo Press          0                  1                    21
# 11107    Penguin Books          0                  5                   261
# 11108    Penguin Books          0                  5                   261
# 11109             Ecco          0                  5                    19
# 11110    Edimat Libros          0                  4                     4
#
#          year  title_length
# 0      2006.0            57
# 1      2004.0            60
# 2      2003.0            58
# 3      2004.0            59
# 4      2004.0            54
# ...       ...           ...
# 11106  2004.0            48
# 11107  1988.0            27
# 11108  1993.0            31
# 11109  2007.0            11
# 11110  2006.0            27
#
# [11111 rows x 13 columns]

# %% [markdown]
# # Create author_count column

# %%
df['author_count'] = df['authors'].apply(lambda x: len(x.split('/')))
df
# Out:
#                                                    title  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 2      Harry Potter and the Chamber of Secrets (Harry...
# 3      Harry Potter and the Prisoner of Azkaban (Harr...
# 4      Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                  ...
# 11106   Expelled from Eden: A William T. Vollmann Reader
# 11107                        You Bright and Risen Angels
# 11108                    The Ice-Shirt (Seven Dreams #1)
# 11109                                        Poor People
# 11110                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11106  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11107                                William T. Vollmann            4.08
# 11108                                William T. Vollmann            3.96
# 11109                                William T. Vollmann            3.72
# 11110                                         Mark Twain            3.91
#
#       language_code  num_pages  ratings_count  text_reviews_count  \
# 0               eng        652        2095690               27591
# 1               eng        870        2153167               29221
# 2               eng        352           6333                 244
# 3               eng        435        2339585               36325
# 4               eng       2690          41428                 164
# ...             ...        ...            ...                 ...
# 11106           eng        512            156                  20
# 11107           eng        635            783                  56
# 11108           eng        415            820                  95
# 11109           eng        434            769                 139
# 11110           spa        272            113                  12
#
#              publisher  audiobook  author_popularity  publisher_popularity  \
# 0      Scholastic Inc.          0                  6                    13
# 1      Scholastic Inc.          0                  6                    13
# 2           Scholastic          0                 11                    33
# 3      Scholastic Inc.          0                  6                    13
# 4           Scholastic          0                  6                    33
# ...                ...        ...                ...                   ...
# 11106    Da Capo Press          0                  1                    21
# 11107    Penguin Books          0                  5                   261
# 11108    Penguin Books          0                  5                   261
# 11109             Ecco          0                  5                    19
# 11110    Edimat Libros          0                  4                     4
#
#          year  title_length  author_count
# 0      2006.0            57             2
# 1      2004.0            60             2
# 2      2003.0            58             1
# 3      2004.0            59             2
# 4      2004.0            54             2
# ...       ...           ...           ...
# 11106  2004.0            48             3
# 11107  1988.0            27             1
# 11108  1993.0            31             1
# 11109  2007.0            11             1
# 11110  2006.0            27             1
#
# [11111 rows x 14 columns]

# %% [markdown]
# # Encoding Variables

# %%
label_encoder = LabelEncoder()
df['title'] = label_encoder.fit_transform(df['title'])
df['authors'] = label_encoder.fit_transform(df['authors'])
df['language_code'] = label_encoder.fit_transform(df['language_code'])
df['publisher'] = label_encoder.fit_transform(df['publisher'])

# %%
df
# Out:
#        title  authors  average_rating  language_code  num_pages  \
# 0       3066     2623            4.57              0        652
# 1       3067     2623            4.49              0        870
# 2       3064     2619            4.42              0        352
# 3       3069     2623            4.56              0        435
# 4       3059     2623            4.78              0       2690
# ...      ...      ...             ...            ...        ...
# 11106   2427     6550            4.06              0        512
# 11107  10204     6549            4.08              0        635
# 11108   7831     6549            3.96              0        415
# 11109   5415     6549            3.72              0        434
# 11110   3945     4113            3.91              9        272
#
#        ratings_count  text_reviews_count  publisher  audiobook  \
# 0            2095690               27591       1778          0
# 1            2153167               29221       1778          0
# 2               6333                 244       1773          0
# 3            2339585               36325       1778          0
# 4              41428                 164       1773          0
# ...              ...                 ...        ...        ...
# 11106            156                  20        497          0
# 11107            783                  56       1485          0
# 11108            820                  95       1485          0
# 11109            769                 139        612          0
# 11110            113                  12        622          0
#
#        author_popularity  publisher_popularity    year  title_length  \
# 0                      6                    13  2006.0            57
# 1                      6                    13  2004.0            60
# 2                     11                    33  2003.0            58
# 3                      6                    13  2004.0            59
# 4                      6                    33  2004.0            54
# ...                  ...                   ...     ...           ...
# 11106                  1                    21  2004.0            48
# 11107                  5                   261  1988.0            27
# 11108                  5                   261  1993.0            31
# 11109                  5                    19  2007.0            11
# 11110                  4                     4  2006.0            27
#
#        author_count
# 0                 2
# 1                 2
# 2                 1
# 3                 2
# 4                 2
# ...             ...
# 11106             3
# 11107             1
# 11108             1
# 11109             1
# 11110             1
#
# [11111 rows x 14 columns]

# %% [markdown]
# # Variable Distributions

# %%
colors = sns.color_palette('husl', n_colors=15)

fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(23, 17), gridspec_kw={'hspace': 0.25})

axes = axes.flatten()

for i, (variable, color) in enumerate(zip(df.columns, colors)):
    sns.histplot(data=df, x=variable, bins=30, kde=True, ax=axes[i], color=color)
    axes[i].set_title(f'Distribution of {variable}')

plt.show()

# %% [markdown]
# # Pearson's Correlation

# %%
cmap = LinearSegmentedColormap.from_list('deep_ocean_blue', ['#00008B', '#EEDD'])
target = 'average_rating'
df2 = pd.concat([df.drop(target,axis=1), df[target]],axis=1)
corr = df2.corr()
plt.figure(figsize=(18,12))
sns.heatmap(corr, annot=True, cmap=cmap, fmt='.2f', linewidths=0.2)
plt.show()

# %%
df.describe()
# Out:
#               title       authors  average_rating  language_code  \
# count  11111.000000  11111.000000    11111.000000   11111.000000
# mean    5170.115921   3333.495635        3.933938       0.273603
# std     2979.902479   1907.699643        0.349870       1.415239
# min        0.000000      0.000000        0.000000       0.000000
# 25%     2596.500000   1673.500000        3.770000       0.000000
# 50%     5175.000000   3331.000000        3.960000       0.000000
# 75%     7763.500000   4982.000000        4.130000       0.000000
# max    10335.000000   6632.000000        5.000000      10.000000
#
#           num_pages  ratings_count  text_reviews_count     publisher  \
# count  11111.000000   1.111100e+04        11111.000000  11111.000000
# mean     337.547475   1.796221e+04          542.632076   1183.297723
# std      240.701238   1.125583e+05         2577.949413    678.088830
# min        0.000000   0.000000e+00            0.000000      0.000000
# 25%      195.000000   1.050000e+02            9.000000    575.500000
# 50%      301.000000   7.480000e+02           47.000000   1226.000000
# 75%      416.000000   5.012000e+03          238.000000   1786.000000
# max     6576.000000   4.597666e+06        94265.000000   2288.000000
#
#          audiobook  author_popularity  publisher_popularity          year  \
# count  11111.00000       11111.000000          11111.000000  11109.000000
# mean       0.01620           4.779858             46.929079   2000.171663
# std        0.12625           6.798525             70.082666      8.247334
# min        0.00000           1.000000              1.000000   1900.000000
# 25%        0.00000           1.000000              5.000000   1998.000000
# 50%        0.00000           2.000000             20.000000   2003.000000
# 75%        0.00000           6.000000             56.000000   2005.000000
# max        1.00000          40.000000            318.000000   2020.000000
#
#        title_length  author_count
# count  11111.000000  11111.000000
# mean      35.724777      1.729817
# std       23.591926      1.820894
# min        2.000000      1.000000
# 25%       18.000000      1.000000
# 50%       31.000000      1.000000
# 75%       47.000000      2.000000
# max      254.000000     51.000000

# %% [markdown]
# # Cheking And Dropping NULLs

# %%
df = df.drop(columns='audiobook')

# %%
df.isna().sum()
# Out:
# title                   0
# authors                 0
# average_rating          0
# language_code           0
# num_pages               0
# ratings_count           0
# text_reviews_count      0
# publisher               0
# author_popularity       0
# publisher_popularity    0
# year                    2
# title_length            0
# author_count            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
colors = sns.color_palette('husl', n_colors=15)

fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(23, 17), gridspec_kw={'hspace': 0.25})

axes = axes.flatten()

for i, (variable, color) in enumerate(zip(df.columns, colors)):
    sns.histplot(data=df, x=variable, bins=30, kde=True, ax=axes[i], color=color)
    axes[i].set_title(f'Distribution of {variable}')

plt.show()

# %% [markdown]
# # Checking For Outliers

# %%
numerical_columns = ['average_rating', 'num_pages', 'ratings_count', 'text_reviews_count', 'title_length', 'author_count', 'author_popularity', 'publisher_popularity']

# box plots
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(3, 5, i)
    sns.boxplot(x=df[column])
    plt.title(f'Box plot of {column}')
    plt.tight_layout()

plt.show()

# %%
def detect_and_treat_outliers(df, columns_to_check):
    for column in columns_to_check:
        q1 = df[column].quantile(0.25)
        q3 = df[column].quantile(0.75)
        iqr = q3 - q1

        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr

        outliers = ((df[column] < lower_bound) | (df[column] > upper_bound))

        df.loc[outliers, column] = df[column].median()

    return df

cols = ['average_rating', 'num_pages', 'ratings_count', 'text_reviews_count', 'title_length', 'author_count', 'author_popularity', 'publisher_popularity']
df = detect_and_treat_outliers(df, cols)

# %%
numerical_columns = ['average_rating', 'num_pages', 'ratings_count', 'text_reviews_count', 'title_length', 'author_count', 'author_popularity', 'publisher_popularity']

# box plots
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(3, 5, i)
    sns.boxplot(x=df[column])
    plt.title(f'Box plot of {column}')
    plt.tight_layout()

plt.show()

# %%
colors = sns.color_palette('husl', n_colors=15)

fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(23, 17), gridspec_kw={'hspace': 0.25})

axes = axes.flatten()

for i, (variable, color) in enumerate(zip(df.columns, colors)):
    sns.histplot(data=df, x=variable, bins=30, kde=True, ax=axes[i], color=color)
    axes[i].set_title(f'Distribution of {variable}')

plt.show()

# %% [markdown]
# # Regression

# %%
df
# Out:
#        title  authors  average_rating  language_code  num_pages  \
# 0       3066     2623            4.57              0        652
# 1       3067     2623            4.49              0        300
# 2       3064     2619            4.42              0        352
# 3       3069     2623            4.56              0        435
# 4       3059     2623            3.96              0        300
# ...      ...      ...             ...            ...        ...
# 11106   2427     6550            4.06              0        512
# 11107  10204     6549            4.08              0        635
# 11108   7831     6549            3.96              0        415
# 11109   5415     6549            3.72              0        434
# 11110   3945     4113            3.91              9        272
#
#        ratings_count  text_reviews_count  publisher  author_popularity  \
# 0                748                  47       1778                  6
# 1                748                  47       1778                  6
# 2               6333                 244       1773                 11
# 3                748                  47       1778                  6
# 4                748                 164       1773                  6
# ...              ...                 ...        ...                ...
# 11106            156                  20        497                  1
# 11107            783                  56       1485                  5
# 11108            820                  95       1485                  5
# 11109            769                 139        612                  5
# 11110            113                  12        622                  4
#
#        publisher_popularity    year  title_length  author_count
# 0                        13  2006.0            57             2
# 1                        13  2004.0            60             2
# 2                        33  2003.0            58             1
# 3                        13  2004.0            59             2
# 4                        33  2004.0            54             2
# ...                     ...     ...           ...           ...
# 11106                    21  2004.0            48             3
# 11107                    20  1988.0            27             1
# 11108                    20  1993.0            31             1
# 11109                    19  2007.0            11             1
# 11110                     4  2006.0            27             1
#
# [11109 rows x 13 columns]

# %%
exp = reg.setup(df, target='average_rating')
# Out:
# <style type="text/css">
# #T_5896c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5896c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5896c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5896c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5896c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5896c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5896c_row0_col1" class="data row0 col1" >4151</td>
#     </tr>
#     <tr>
#       <th id="T_5896c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5896c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5896c_row1_col1" class="data row1 col1" >average_rating</td>
#     </tr>
#     <tr>
#       <th id="T_5896c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5896c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5896c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5896c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5896c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_
_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1174c_row2_col0" class="data row2 col0" >0.1890</td>
#       <td id="T_1174c_row2_col1" class="data row2 col1" >0.0568</td>
#       <td id="T_1174c_row2_col2" class="data row2 col2" >0.2383</td>
#       <td id="T_1174c_row2_col3" class="data row2 col3" >0.1559</td>
#       <td id="T_1174c_row2_col4" class="data row2 col4" >0.0485</td>
#       <td id="T_1174c_row2_col5" class="data row2 col5" >0.0484</td>
#     </tr>
#     <tr>
#       <th id="T_1174c_level0_row3" class="row_heading level0 row3" >Mean</th>
#       <td id="T_1174c_row3_col0" class="data row3 col0" >0.1863</td>
#       <td id="T_1174c_row3_col1" class="data row3 col1" >0.0555</td>
#       <td id="T_1174c_row3_col2" class="data row3 col2" >0.2356</td>
#       <td id="T_1174c_row3_col3" class="data row3 col3" >0.1594</td>
#       <td id="T_1174c_row3_col4" class="data row3 col4" >0.0480</td>
#       <td id="T_1174c_row3_col5" class="data row3 col5" >0.0477</td>
#     </tr>
#     <tr>
#       <th id="T_1174c_level0_row4" class="row_heading level0 row4" >Std</th>
#       <td id="T_1174c_row4_col0" class="data row4 col0" >0.0025</td>
#       <td id="T_1174c_row4_col1" class="data row4 col1" >0.0011</td>
#       <td id="T_1174c_row4_col2" class="data row4 col2" >0.0024</td>
#       <td id="T_1174c_row4_col3" class="data row4 col3" >0.0067</td>
#       <td id="T_1174c_row4_col4" class="data row4 col4" >0.0005</td>
#       <td id="T_1174c_row4_col5" class="data row4 col5" >0.0008</td>
#     </tr>
#   </tbody>
# </table>

# %%
reg.evaluate_model(lightgbm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
reg.save_model(lightgbm, 'RegressionModel')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['title', 'authors',
#                                               'language_code', 'num_pages',
#                                               'ratings_count',
#                                               'text_reviews_count', 'publisher',
#                                               'author_popularity',
#                                               'publisher_popularity', 'year',
#                                               'title_length', 'author_count'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model', LGBMRegressor(n_jobs=-1, random_state=4151))]),
#  'RegressionModel.pkl')

# %% [markdown]
# # Classification

# %% [markdown]
# Creation of a new column 'class' in the DataFrame by categorizing the average ratings with labels 'BAD', 'Medium', and 'Good' according to predefined intervals.

# %%
# Define new bins and labels
bins = [-float('inf'), 3.8, 4.1, float('inf')]  # Adjusted intervals
labels = ['BAD', 'Medium', 'Good']  # Updated labels

# Cut the 'average_rating' column into intervals and assign labels
df['class'] = pd.cut(df['average_rating'], bins=bins, labels=labels, include_lowest=True)

# Check the distribution of classes
class_counts = df['class'].value_counts()
print(class_counts)
# Out:
# class
# Medium    4981
# Good      3150
# BAD       2978
# Name: count, dtype: int64

# %%
# Assuming df is your DataFrame
X = df.drop('class', axis=1)  # Features
y = df['class']  # Target

# Apply SMOTE to balance the dataset
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)
# Print class distribution after applying SMOTE
print("After SMOTE:", Counter(y_resampled))
# Out:
# After SMOTE: Counter({'Good': 4981, 'Medium': 4981, 'BAD': 4981})

# %%
# Combine resampled X and y into a DataFrame
new_df_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['class'])], axis=1)

# %%
new_df = new_df_resampled.drop("average_rating", axis=1)

encoder = LabelEncoder()
new_df['class'] = encoder.fit_transform(new_df['class'])

# %% [markdown]
# Charger PyCaret et configurer votre expérience de classification :

# %%
exp_clf = clf.setup(data=new_df, target='class')
# Out:
# <style type="text/css">
# #T_d609c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d609c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d609c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d609c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d609c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d609c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d609c_row0_col1" class="data row0 col1" >5506</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d609c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d609c_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d609c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d609c_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d609c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d609c_row3_col1" class="data row3 col1" >(14943, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d609c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d609c_row4_col1" class="data row4 col1" >(14943, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d609c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d609c_row5_col1" class="data row5 col1" >(10460, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d609c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d609c_row6_col1" class="data row6 col1" >(4483, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d609c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d609c_row7_col1" class="data row7 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d609c_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_d609c_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d609c_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_d609c_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d609c_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_d609c_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d609c_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_d609c_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d609c_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_d609c_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d609c_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_d609c_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d609c_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_d609c_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d609c_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_d609c_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d609c_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_d609c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d609c_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_d609c_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d609c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d609c_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_d609c_row18_col1" class="data row18 col1" >1956</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Similarly to the regression case, clf.compare_models() will compare the multiple classification models, and since the running time could be long, the following cell can be skipped, however, te results table is still available:

# %%
best_model = clf.compare_models(fold=3)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             03:09:42
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_73ce5 th {
#   text-align: left;
# }
# #T_73ce5_row0_col0, #T_73ce5_row0_col2, #T_73ce5_row1_col0, #T_73ce5_row1_col1, #T_73ce5_row1_col3, #T_73ce5_row1_col4, #T_73ce5_row1_col5, #T_73ce5_row1_col6, #T_73ce5_row1_col7, #T_73ce5_row2_col0, #T_73ce5_row2_col1, #T_73ce5_row2_col2, #T_73ce5_row2_col3, #T_73ce5_row2_col4, #T_73ce5_row2_col5, #T_73ce5_row2_col6, #T_73ce5_row2_col7, #T_73ce5_row3_col0, #T_73ce5_row3_col1, #T_73ce5_row3_col2, #T_73ce5_row3_col3, #T_73ce5_row3_col4, #T_73ce5_row3_col5, #T_73ce5_row3_col6, #T_73ce5_row3_col7, #T_73ce5_row4_col0, #T_73ce5_row4_col1, #T_73ce5_row4_col2, #T_73ce5_row4_col3, #T_73ce5_row4_col4, #T_73ce5_row4_col5, #T_73ce5_row4_col6, #T_73ce5_row4_col7, #T_73ce5_row5_col0, #T_73ce5_row5_col1, #T_73ce5_row5_col2, #T_73ce5_row5_col3, #T_73ce5_row5_col4, #T_73ce5_row5_col5, #T_73ce5_row5_col6, #T_73ce5_row5_col7, #T_73ce5_row6_col0, #T_73ce5_row6_col1, #T_73ce5_row6_col2, #T_73ce5_row6_col3, #T_73ce5_row6_col4, #T_73ce5_row6_col5, #T_73ce5_row6_col6, #T_73ce5_row6_col7, #T_73ce5_row7_col0, #T_73ce5_row7_col1, #T_73ce5_row7_col2, #T_73ce5_row7_col3, #T_73ce5_row7_col4, #T_73ce5_row7_col5, #T_73ce5_row7_col6, #T_73ce5_row7_col7, #T_73ce5_row8_col0, #T_73ce5_row8_col1, #T_73ce5_row8_col2, #T_73ce5_row8_col3, #T_73ce5_row8_col4, #T_73ce5_row8_col5, #T_73ce5_row8_col6, #T_73ce5_row8_col7, #T_73ce5_row9_col0, #T_73ce5_row9_col1, #T_73ce5_row9_col2, #T_73ce5_row9_col3, #T_73ce5_row9_col4, #T_73ce5_row9_col5, #T_73ce5_row9_col6, #T_73ce5_row9_col7, #T_73ce5_row10_col0, #T_73ce5_row10_col1, #T_73ce5_row10_col2, #T_73ce5_row10_col3, #T_73ce5_row10_col4, #T_73ce5_row10_col5, #T_73ce5_row10_col6, #T_73ce5_row10_col7, #T_73ce5_row11_col0, #T_73ce5_row11_col1, #T_73ce5_row11_col2, #T_73ce5_row11_col3, #T_73ce5_row11_col4, #T_73ce5_row11_col5, #T_73ce5_row11_col6, #T_73ce5_row11_col7, #T_73ce5_row12_col0, #T_73ce5_row12_col1, #T_73ce5_row12_col2, #T_73ce5_row12_col3, #T_73ce5_row12_col4, #T_73ce5_row12_col5, #T_73ce5_row12_col6, #T_73ce5_row12_col7 {
#   text-align: left;
# }
# #T_73ce5_row0_col1, #T_73ce5_row0_col3, #T_73ce5_row0_col4, #T_73ce5_row0_col5, #T_73ce5_row0_col6, #T_73ce5_row0_col7, #T_73ce5_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_73ce5_row0_col8, #T_73ce5_row1_col8, #T_73ce5_row2_col8, #T_73ce5_row3_col8, #T_73ce5_row4_col8, #T_73ce5_row5_col8, #T_73ce5_row6_col8, #T_73ce5_row7_col8, #T_73ce5_row9_col8, #T_73ce5_row10_col8, #T_73ce5_row11_col8, #T_73ce5_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_73ce5_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_73ce5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73ce5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_73ce5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_73ce5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_73ce5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_73ce5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_73ce5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_73ce5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_73ce5_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_73ce5_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73ce5_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_73ce5_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_73ce5_row0_col1" class="data row0 col1" >0.5569</td>
#       <td id="T_73ce5_row0_col2" class="data row0 col2" >0.7458</td>
#       <td id="T_73ce5_row0_col3" class="data row0 col3" >0.5569</td>
#       <td id="T_73ce5_row0_col4" class="data row0 col4" >0.5536</td>
#       <td id="T_73ce5_row0_col5" class="data row0 col5" >0.5540</td>
#       <td id="T_73ce5_row0_col6" class="data row0 col6" >0.3353</td>
#       <td id="T_73ce5_row0_col7" class="data row0 col7" >0.3361</td>
#       <td id="T_73ce5_row0_col8" class="data row0 col8" >0.2667</td>
#     </tr>
#     <tr>
#       <th id="T_73ce5_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_73ce5_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_73ce5_row1_col1" class="data row1 col1" >0.5564</td>
#       <td id="T_73ce5_row1_col2" class="data row1 col2" >0.7535</td>
#       <td id="T_73ce5_row1_col3" class="data row1 col3" >0.5564</td>
#       <td id="T_73ce5_row1_col4" class="data row1 col4" >0.5532</td>
#       <td id="T_73ce5_row1_col5" class="data row1 col5" >0.5536</td>
#       <td id="T_73ce5_row1_col6" class="data row1 col6" >0.3346</td>
#       <td id="T_73ce5_row1_col7" class="data row1 col7" >0.3354</td>
#       <td id="T_73ce5_row1_col8" class="data row1 col8" >0.1733</td>
#     </tr>
#     <tr>
#       <th id="T_73ce5_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_73ce5_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_73ce5_row2_col1" class="data row2 col1" >0.5086</td>
#       <td id="T_73ce5_row2_col2" class="data row2 col2" >0.7048</td>
#       <td id="T_73ce5_row2_col3" class="data row2 col3" >0.5086</td>
#       <td id="T_73ce5_row2_col4" class="data row2 col4" >0.5070</td>
#       <td id="T_73ce5_row2_col5" class="data row2 col5" >0.5044</td>
#       <td id="T_73ce5_row2_col6" class="data row2 col6" >0.2629</td>
#       <td id="T_73ce5_row2_col7" class="data row2 col7" >0.2646</td>
#       <td id="T_73ce5_row2_col8" class="data row2 col8" >1.5133</td>
#     </tr>
#     <tr>
#       <th id="T_73ce5_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_73ce5_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_73ce5_row3_col1" class="data row3 col1" >0.4720</td>
#       <td id="T_73ce5_row3_col2" class="data row3 col2" >0.6486</td>
#       <td id="T_73ce5_row3_col3" class="data row3 col3" >0.4720</td>
#       <td id="T_73ce5_row3_col4" class="data row3 col4" >0.4672</td>
#       <td id="T_73ce5_row3_col5" class="data row3 col5" >0.4584</td>
#       <td id="T_73ce5_row3_col6" class="data row3 col6" >0.2080</td>
#       <td id="T_73ce5_row3_col7" class="data row3 col7" >0.2129</td>
#       <td id="T_73ce5_row3_col8" class="data row3 col8" >0.4233</td>
#     </tr>
#     <tr>
#       <th id="T_73ce5_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_73ce5_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_73ce5_row4_col1" class="data row4 col1" >0.4680</td>
#       <td id="T_73ce5_row4_col2" class="data row4 col2" >0.6496</td>
#       <td id="T_73ce5_row4_col3" class="data row4 col3" >0.4680</td>
#       <td id="T_73ce5_row4_col4" class="data row4 col4" >0.4640</td>
#       <td id="T_73ce5_row4_col5" class="data row4 col5" >0.4593</td>
#       <td id="T_73ce5_row4_col6" class="data row4 col6" >0.2020</td>
#       <td id="T_73ce5_row4_col7" class="data row4 col7" >0.2047</td>
#       <td id="T_73ce5_row4_col8" class="data row4 col8" >0.1500</td>
#     </tr>
#     <tr>
#       <th id="T_73ce5_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_73ce5_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_73ce5_row5_col1" class="data row5 col1" >0.4551</td>
#       <td id="T_73ce5_row5_col2" class="data row5 col2" >0.5913</td>
#       <td id="T_73ce5_row5_col3" class="data row5 col3" >0.4551</td>
#       <td id="T_73ce5_row5_col4" class="data row5 col4" >0.4551</td>
#       <td id="T_73ce5_row5_col5" class="data row5 col5" >0.4550</td>
#       <td id="T_73ce5_row5_col6" class="data row5 col6" >0.1826</td>
#       <td id="T_73ce5_row5_col7" class="data row5 col7" >0.1826</td>
#       <td id="T_73ce5_row5_col8" class="data row5 col8" >0.3833</td>
#     </tr>
#     <tr>
#       <th id="T_73ce5_level0_row6" class="row_heading level0 row6" >lda</th>
#       <td id="T_73ce5_row6_col0" class=

# %% [markdown]
# Adjusting the hyperparameters of the best model:

# %%
tuned_model = clf.tune_model(best_model)
# Out:
# <style type="text/css">
# #T_9148d_row10_col0, #T_9148d_row10_col1, #T_9148d_row10_col2, #T_9148d_row10_col3, #T_9148d_row10_col4, #T_9148d_row10_col5, #T_9148d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9148d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9148d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9148d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9148d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9148d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9148d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9148d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9148d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9148d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9148d_row0_col0" class="data row0 col0" >0.5076</td>
#       <td id="T_9148d_row0_col1" class="data row0 col1" >0.7034</td>
#       <td id="T_9148d_row0_col2" class="data row0 col2" >0.5076</td>
#       <td id="T_9148d_row0_col3" class="data row0 col3" >0.5075</td>
#       <td id="T_9148d_row0_col4" class="data row0 col4" >0.5001</td>
#       <td id="T_9148d_row0_col5" class="data row0 col5" >0.2615</td>
#       <td id="T_9148d_row0_col6" class="data row0 col6" >0.2651</td>
#     </tr>
#     <tr>
#       <th id="T_9148d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9148d_row7_col0" class="data row7 col0" >0.5220</td>
#       <td id="T_9148d_row7_col1" class="data row7 col1" >0.6997</td>
#       <td id="T_9148d_row7_col2" class="data row7 col2" >0.5220</td>
#       <td id="T_9148d_row7_col3" class="data row7 col3" >0.5180</td>
#       <td id="T_9148d_row7_col4" class="data row7 col4" >0.5098</td>
#       <td id="T_9148d_row7_col5" class="data row7 col5" >0.2831</td>
#       <td id="T_9148d_row7_col6" class="data row7 col6" >0.2884</td>
#     </tr>
#     <tr>
#       <th id="T_9148d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9148d_row8_col0" class="data row8 col0" >0.5143</td>
#       <td id="T_9148d_row8_col1" class="data row8 col1" >0.7081</td>
#       <td id="T_9148d_row8_col2" class="data row8 col2" >0.5143</td>
#       <td id="T_9148d_row8_col3" class="data row8 col3" >0.5095</td>
#       <td id="T_9148d_row8_col4" class="data row8 col4" >0.5016</td>
#       <td id="T_9148d_row8_col5" class="data row8 col5" >0.2716</td>
#       <td id="T_9148d_row8_col6" class="data row8 col6" >0.2768</td>
#     </tr>
#     <tr>
#       <th id="T_9148d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9148d_row9_col0" class="data row9 col0" >0.5076</td>
#       <td id="T_9148d_row9_col1" class="data row9 col1" >0.7069</td>
#       <td id="T_9148d_row9_col2" class="data row9 col2" >0.5076</td>
#       <td id="T_9148d_row9_col3" class="data row9 col3" >0.5062</td>
#       <td id="T_9148d_row9_col4" class="data row9 col4" >0.4982</td>
#       <td id="T_9148d_row9_col5" class="data row9 col5" >0.2616</td>
#       <td id="T_9148d_row9_col6" class="data row9 col6" >0.2659</td>
#     </tr>
#     <tr>
#       <th id="T_9148d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9148d_row10_col0" class="data row10 col0" >0.5078</td>
#       <td id="T_9148d_row10_col1" class="data row10 col1" >0.7013</td>
#       <td id="T_9148d_row10_col2" class="data row10 col2" >0.5078</td>
#       <td id="T_9148d_row10_col3" class="data row10 col3" >0.5045</td>
#       <td id="T_9148d_row10_col4" class="data row10 col4" >0.4980</td>
#       <td id="T_9148d_row10_col5" class="data row10 col5" >0.2618</td>
#       <td id="T_9148d_row10_col6" class="data row10 col6" >0.2658</td>
#     </tr>
#     <tr>
#       <th id="T_9148d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9148d_row11_col0" class="data row11 col0" >0.0162</td>
#       <td id="T_9148d_row11_col1" class="data row11 col1" >0.0151</td>
#       <td id="T_9148d_row11_col2" class="data row11 col2" >0.0162</td>
#       <td id="T_9148d_row11_col3" class="data row11 col3" >0.0164</td>
#       <td id="T_9148d_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# Assessing the fitted model:

# %%
clf.evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
clf.save_model(tuned_model, 'ClassificationModel')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['title', 'authors',
#                                               'language_code', 'num_pages',
#                                               'ratings_count',
#                                               'text_reviews_count', 'publisher',
#                                               'author_popularity',
#                                               'publisher_popularity', 'year',
#                                               'title_length', 'author_count'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, n_estimators=100,
#                                          n_jobs=-1, oob_score=False,
#                                          random_state=2890, verbose=0,
#                                          warm_start=False))],
#           verbose=False),
#  'ClassificationModel.pkl')
